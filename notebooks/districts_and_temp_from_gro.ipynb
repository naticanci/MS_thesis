# %% [markdown]
# <a href="https://colab.research.google.com/github/naticanci/MS_thesis/blob/main/DISTRICTS_AND_TEMPERATURE_FROM_GRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip install geopandas
# !pip install geojson
import geopandas as gpd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
df_places = gpd.read_file('/content/drive/MyDrive/MASTERS/Thesis topic/Data/countries.geojson')

# %%
df_places.head(5)
# Out:
#          ADMIN ISO_A3                                           geometry
# 0        Aruba    ABW  POLYGON ((-69.99694 12.57758, -69.93639 12.531...
# 1  Afghanistan    AFG  POLYGON ((71.04980 38.40866, 71.05714 38.40903...
# 2       Angola    AGO  MULTIPOLYGON (((11.73752 -16.69258, 11.73851 -...
# 3     Anguilla    AIA  MULTIPOLYGON (((-63.03767 18.21296, -63.09952 ...
# 4      Albania    ALB  POLYGON ((19.74777 42.57890, 19.74601 42.57993...

# %%
PATH = '/content/drive/MyDrive/MASTERS/Gro-DATA/'

# %%
import fiona
fiona.supported_drivers

# %%
df_places = gpd.read_file(PATH+"districtsdataframe.shp")
df_places
# Out:
#         district                                           geometry
# 0         100001  POLYGON ((70.91731 37.14584, 70.96329 37.12470...
# 1         100002  POLYGON ((70.99173 38.48968, 70.99430 38.44852...
# 2         100003  POLYGON ((70.76271 37.28587, 70.73604 37.25875...
# 3         100004  POLYGON ((71.63568 36.69001, 71.60624 36.67195...
# 4         100005  POLYGON ((70.99876 36.91148, 71.01936 36.88481...
# ...          ...                                                ...
# 42422  100022663  POLYGON ((130.76734 -12.44313, 130.76733 -12.4...
# 42423  100022664  POLYGON ((130.23929 -13.28196, 130.29053 -13.3...
# 42424  100022665  MULTIPOLYGON (((130.93047 -25.26525, 130.93048...
# 42425  100022666  POLYGON ((149.20070 -35.20541, 149.21379 -35.2...
# 42426  100022667  POLYGON ((150.70160 -35.12286, 150.71746 -35.1...
#
# [42427 rows x 2 columns]

# %%
df_temp = pd.read_csv(PATH+'MinMaxTempWorld.csv')
df_temp
# Out:
#           min_temp  region_id  year  month   max_temp
# 0       -45.364172     100001  2001      1 -13.625138
# 1       -43.769263     100001  2001      2  -8.317419
# 2       -34.295325     100001  2001      3  -3.882971
# 3       -26.257320     100001  2001      4  -1.461605
# 4       -31.416134     100001  2001      5  12.433801
# ...            ...        ...   ...    ...        ...
# 5599435   9.402307  100022667  2011      8  18.094934
# 5599436  12.036768  100022667  2011      9  20.862288
# 5599437  13.115869  100022667  2011     10  27.660364
# 5599438  13.192611  100022667  2011     11  31.560409
# 5599439  15.298608  100022667  2011     12  28.478906
#
# [5599440 rows x 5 columns]
